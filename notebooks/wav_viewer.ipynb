# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle

# %%
data = pickle.load(open('../datasets/RML2016.10a_debug_dict.dat', 'rb'))

# %%
data.keys()
# Out:
# dict_keys([('BPSK', 'clean'), ('QPSK', 'clean'), ('8PSK', 'clean'), ('QAM16', 'clean'), ('QAM64', 'clean'), ('GFSK', 'clean'), ('CPFSK', 'clean'), ('WBFM', 'clean'), ('AM-DSB', 'clean'), ('AM-SSB', 'clean')])

# %%
idx = 0
mod_type = 'AM-SSB'
mod_data = data[(mod_type, 'clean')]
wave = data[(mod_type, 'clean')][idx]

# %%
mod_data.shape
# Out:
# (100, 2, 1024)

# %%
plt.plot(wave.transpose(), '.-')

# %%
plt.plot(wave[0], wave[1], '*-')
