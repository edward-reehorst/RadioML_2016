# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from gnuradio import gr, blocks, analog

# %%
dis_sig = np.load('../discrete_source.npy')

# %%
cont_sig = np.load('../continous_source.npy')

# %%
plt.plot(dis_sig[:100])
# Out:
# /Users/edwardreehorst/anaconda3/envs/gnuradio/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
plt.plot(cont_sig)
# Out:
# /Users/edwardreehorst/anaconda3/envs/gnuradio/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1333: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
src = blocks.wavfile_source('../source/long_way.wav')

# %%
tb = gr.top_block()
snk = blocks.vector_sink_f()
limit = blocks.head(gr.sizeof_float, 1000)
tb.connect(src, limit, snk)
tb.run()
output_vector = np.array(snk.data(), dtype=np.complex64)

# %%
plt.plot(output_vector.real)
